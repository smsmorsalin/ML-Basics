# %% [markdown]
# <a href="https://colab.research.google.com/github/smsmorsalin/ML-Basics/blob/main/EDA_using_Bivariate_and_Multivariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
titanic = pd.read_csv('/content/train.csv')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

# %% [markdown]
# 1. **scatterplot(Numerical - Numerical)**

# %% [markdown]
# to visualize the relationship between `total_bill` and `tip` from the `tips` dataset, you would specify both `x` and `y` parameters like this:

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex',style='smoker', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 2. BarPlot (Numerical - Categorical)

# %%
sns.barplot(titanic, x='Pclass', y='Age', hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# 3. BoxPlot(Numerical - Categorical)

# %%
sns.boxenplot(titanic, x='Sex', y='Age', hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# 4. DistPlot (Numerical - Categorical)

# %%
sns.displot(titanic[titanic['Survived']==0]['Age'])
sns.displot(titanic[titanic['Survived']==1]['Age'])

# %% [markdown]
# 5. HeatMap (categorical - categorical)

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'], titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# (titanic.groupby('Embarked').mean()['Survived']*100)

# %% [markdown]
# 6. ClusterMap (categorical - Categotrical)

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'], titanic['Survived']))

# %% [markdown]
# 7. PairPlot (Numerical - Numerical)

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# 8. LinePlot (Numerical - Numerical)

# %%
sns.lineplot(flights, x='year', y='passengers')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
